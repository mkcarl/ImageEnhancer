# %%
from PIL import Image, ImageFilter, ImageEnhance
import cv2, numpy as np

# %%
im = Image.open("images_png/0.png")
im
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=700x479 at 0x2167D2E9F10>

# %%
imEnhance = ImageEnhance.Brightness(im)
imEnhance.enhance(1.4)
# Out:
# <PIL.Image.Image image mode=RGB size=700x479 at 0x2167D2E9FD0>

# %%
imEnhance.enhance(1.4).filter(ImageFilter.SMOOTH)
# Out:
# <PIL.Image.Image image mode=RGB size=700x479 at 0x2167EB015E0>
